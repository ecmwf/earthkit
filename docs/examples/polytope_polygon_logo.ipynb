# %% [markdown]
# ## Polytope polygons forming a word

# %% [markdown]
# This example retrieves polygon coverages forming the word "POLYTOPE" from polytope and plots it onto a map.

# %%
import earthkit.data as ekd
import earthkit.plots as ekp

# define the polygons
shape1 = [
    [7.258763811234218, 48.793723130601535],
    [7.168488316250347, 49.83398497089428],
    [8.21596726115746, 49.850900108140536],
    [8.22477419294512, 49.63238869079714],
    [7.425045773152021, 49.6375037902404],
    [7.488604743081794, 48.76751542040529],
    [7.262985428883866, 48.762974824632806],
],

shape2 = [
    [8.228175484385758, 49.62363905618946],
    [8.2383404847414, 49.30577331470633],
    [7.468517996271913, 49.29035950951544],
    [7.442698254298165, 49.394063349552624],
    [8.0965165757963, 49.41322522398369],
    [8.09028856771124, 49.63518066374158],
]

shape3 = [
    [8.778584932744309, 49.86954658650521],
    [8.862295524771469, 48.766918864990714],
    [10.061878585703141, 48.80521538773752],
    [10.05189374814043, 49.02912712169905],
    [9.126374708842917, 49.035317308040874],
    [9.054787898083248, 49.85647839775169],
    [8.79447274483195, 49.8646339236731],
]

shape4 = [
    [9.088892121315212, 49.68396293291025],
    [9.819571610135483, 49.684014501470756],
    [9.85505960658449, 49.03116952568445],
    [10.060153571012052, 49.027505122195635],
    [10.072160282281033, 49.86449197101945],
    [9.05948442169526, 49.85694532601448],
    [9.071912795654185, 49.68014004987609],
]

shape5 = [
    [10.598471035757996, 49.82012849229719],
    [10.623393389597027, 48.824858944891844],
    [12.04024144738159, 48.83198005307881],
    [12.006769966371252, 49.16097358155085],
    [10.989756517888907, 49.16815641449875],
    [10.948052430339942, 49.88592726422476],
    [10.596882802957197, 49.86398061258498],
]

shape6 = [
    [13.29197987307927, 49.97728585641272],
    [12.57111275146977, 49.97104094778115],
    [13.222322323273431, 49.37725327518439],
    [13.202971158951414, 48.903129615084254],
    [13.827804957331438, 48.88340416595227],
    [13.874384556433938, 49.40358865952578],
    [14.605299546055448, 49.93197478940584],
    [14.102062445091747, 49.98001098000407],
    [13.624487089218775, 49.55461007587729],
    [13.3099890365134, 49.97739580806973],
]

shape7 = [
    [15.228965549991614, 49.730373613580525],
    [15.230125323821682, 50.090633313563075],
    [17.660387372585035, 50.06822116337625],
    [17.577939895914568, 49.59398017760927],
    [16.752386182433355, 49.64920447268295],
    [16.58109059401943, 48.772986118860814],
    [16.094304206428518, 48.79160176954642],
    [16.185638387834643, 49.640410835320694],
    [15.250602552532541, 49.68736034043533],
]

shape8 = [
    [18.006103810711153, 49.874817453680265],
    [17.872892800864577, 48.7751276419595],
    [19.231045390320162, 48.68751356669205],
    [19.286273043798417, 48.9720484447422],
    [18.331513679782546, 49.02466456647059],
    [18.4410677556115, 49.91883884509102],
    [17.990407455442124, 49.9284320053506],
]

shape9 = [
    [18.523099688262818, 49.91693240270905],
    [19.571993355132093, 49.88820196224816],
    [19.269541055964595, 48.99870007380369],
    [18.989650825560034, 49.00717933216285],
    [19.1721361339051, 49.67352579852684],
    [18.42049036941708, 49.71965669030075],
    [18.436899591803154, 49.93131406908293],
]

shape10 = [
    [20.369665233263703, 48.68540724766882],
    [20.390795716706066, 49.82142033684306],
    [21.66474097162009, 49.77219361759094],
    [21.599781134603887, 49.45580574399338],
    [20.770239556798373, 49.481617120321545],
    [20.773898383565665, 48.68594678666463],
    [20.369665233263703, 48.68540724766882],
]

shape11 = [
    [20.779400086097894, 49.266396683614516],
    [21.291684316951347, 49.25582141560005],
    [21.29255644055283, 49.462413633894414],
    [21.60241816111113, 49.44412952745972],
    [21.577574878322366, 49.16620350494162],
    [20.792010318248543, 49.16233120403493],
    [20.768637193550887, 49.273598233154075],
]

shape12 = [
    [23.208137901360374, 49.651584260796994],
    [22.09658437133257, 49.752545184049126],
    [21.91802865423628, 48.67264127283525],
    [23.391185304246818, 48.62884428299256],
    [23.420678366377672, 48.95370738548149],
    [22.47620509293023, 48.948108124274114],
    [22.504379835652145, 49.154931298807696],
    [23.380718740911448, 49.134280180441834],
    [23.347965550435475, 49.36007407350195],
    [22.508043914644247, 49.34861103718032],
    [22.552065252592882, 49.49663569230876],
    [23.44022825068265, 49.49121931651345],
    [23.257411122842967, 49.664632737235905],
]


request_pattern = {
    "class": "od",
    "stream" : "enfo",
    "type" : "pf",
    "date" : "20241114",
    "time" : "1200",
    "levtype" : "sfc",
    "expver" : 1,
    "domain" : "g",
    "param" : "167",
    "number" : "1",
    "step": "0",
}

chart = ekp.Map(domain="Europe")

for shape in [shape1, shape2, shape3, shape4, shape5, shape6, shape7, shape8, shape9, shape10, shape11, shape12]:

    # retrive the given coverage from polytope and convert into Xarray
    request = dict(**request_pattern)
    request["feature"] = {"type": "polygon", "shape": shape}

    ds = ekd.from_source("polytope", "ecmwf-mars-beta", request, stream=False, 
                         address='polytope-test.ecmwf.int').to_xarray()

    # add the Xarray dataset to the plot
    chart.point_cloud(ds['2t'], x="x", y="y",s=0.1)

# generate the plot
chart.coastlines()
chart.borders()
chart.gridlines()
 
chart.title("{variable_name} (number={number})")
 
chart.show()
# Out:
# 2024-11-15 13:25:32 - INFO - Key read from /Users/cgr/.polytopeapirc
# 2024-11-15 13:25:32 - INFO - Sending request...
# {'request': 'class: od\n'
#             "date: '20241114'\n"
#             'domain: g\n'
#             'expver: 1\n'
#             'feature:\n'
#             '  shape:\n'
#             '  - - - 7.258763811234218\n'
#             '      - 48.793723130601535\n'
#             '    - - 7.168488316250347\n'
#             '      - 49.83398497089428\n'
#             '    - - 8.21596726115746\n'
#             '      - 49.850900108140536\n'
#             '    - - 8.22477419294512\n'
#             '      - 49.63238869079714\n'
#             '    - - 7.425045773152021\n'
#             '      - 49.6375037902404\n'
#             '    - - 7.488604743081794\n'
#             '      - 48.76751542040529\n'
#             '    - - 7.262985428883866\n'
#             '      - 48.762974824632806\n'
#             '  type: polygon\n'
#             'levtype: sfc\n'
#             "number: '1'\n"
#             "param: '167'\n"
#             "step: '0'\n"
#             'stream: enfo\n'
#             "time: '1200'\n"
#             'type: pf\n',
#  'verb': 'retrieve'}
# 2024-11-15 13:25:32 - INFO - Polytope user key found in session cache for user cgr
# 2024-11-15 13:25:33 - INFO - Request accepted. Please poll ./f14804f3-042c-4754-947f-49f6ac973ac4 for status
# 2024-11-15 13:25:33 - INFO - Polytope user key found in session cache for user cgr
# 2024-11-15 13:25:33 - INFO - Checking request status (./f14804f3-042c-4754-947f-49f6ac973ac4)...
# 2024-11-15 13:25:34 - INFO - The current status of the request is 'processing'
# 2024-11-15 13:25:35 - INFO - The current status of the request is 'processed'
# f14804f3-042c-4754-947f-49f6ac973ac4.covjson:   0%|          | 0.00/5.91k [00:00<?, ?B/s]
# DEBUG:polytope.api.Client.DMFTG0:Gathered Polytope client configuration:
# {'address': 'polytope-test.ecmwf.int',
#  'insecure': False,
#  'key_path': PosixPath('/Users/cgr/.polytopeapirc'),
#  'log_file': None,
#  'log_level': 'DEBUG',
#  'password': None,
#  'port': None,
#  'quiet': False,
#  'skip_tls': False,
#  'user_email': None,
#  'user_key': None,
#  'username': 'cgr',
#  'verbose': False}
# DEBUG:polytope.api.Client.DMFTG0:Creating Polytope client...
# 2024-11-15 13:25:36 - INFO - Key read from /Users/cgr/.polytopeapirc
# INFO:polytope.api.Client.DMFTG0:Key read from /Users/cgr/.polytopeapirc
# 2024-11-15 13:25:36 - INFO - Sending request...
# {'request': 'class: od\n'
#             "date: '20241114'\n"
#             'domain: g\n'
#             'expver: 1\n'
#             'feature:\n'
#             '  shape:\n'
#             '  - - 8.228175484385758\n'
#             '    - 49.62363905618946\n'
#             '  - - 8.2383404847414\n'
#             '    - 49.30577331470633\n'
#             '  - - 7.468517996271913\n'
#             '    - 49.29035950951544\n'
#             '  - - 7.442698254298165\n'
#             '    - 49.394063349552624\n'
#             '  - - 8.0965165757963\n'
#             '    - 49.41322522398369\n'
#             '  - - 8.09028856771124\n'
#             '    - 49.63518066374158\n'
#             '  type: polygon\n'
#             'levtype: sfc\n'
#             "number: '1'\n"
#             "param: '167'\n"
#             "step: '0'\n"
#             'stream: enfo\n'
#             "time: '1200'\n"
#             'type: pf\n',
#  'verb': 'retrieve'}
# INFO:polytope.api.Client.DMFTG0:Sending request...
# {'request': 'class: od\n'
#             "date: '20241114'\n"
#             'domain: g\n'
#             'expver: 1\n'
#             'feature:\n'
#             '  shape:\n'
#             '  - - 8.228175484385758\n'
#             '    - 49.62363905618946\n'
#             '  - - 8.2383404847414\n'
#             '    - 49.30577331470633\n'
#             '  - - 7.468517996271913\n'
#             '    - 49.29035950951544\n'
#             '  - - 7.442698254298165\n'
#             '    - 49.394063349552624\n'
#             '  - - 8.0965165757963\n'
#             '    - 49.41322522398369\n'
#             '  - - 8.09028856771124\n'
#             '    - 49.63518066374158\n'
#             '  type: polygon\n'
#             'levtype: sfc\n'
#             "number: '1'\n"
#             "param: '167'\n"
#             "step: '0'\n"
#             'stream: enfo\n'
#             "time: '1200'\n"
#             'type: pf\n',
#  'verb': 'retrieve'}
# 2024-11-15 13:25:36 - INFO - Polytope user key found in session cache for user cgr
# INFO:polytope.api.Client.DMFTG0:Polytope user key found in session cache for user cgr
# DEBUG:polytope.api.Client.DMFTG0:Polytope client attempting HTTP POST https://polytope-test.ecmwf.int:443/api/v1/requests/ecmwf-mars-beta
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': {'verb': 'retrieve', 'request': "class: od\ndate: '20241114'\ndomain: g\nexpver: 1\nfeature:\n  shape:\n  - - 8.228175484385758\n    - 49.62363905618946\n  - - 8.2383404847414\n    - 49.30577331470633\n  - - 7.468517996271913\n    - 49.29035950951544\n  - - 7.442698254298165\n    - 49.394063349552624\n  - - 8.0965165757963\n    - 49.41322522398369\n  - - 8.09028856771124\n    - 49.63518066374158\n  type: polygon\nlevtype: sfc\nnumber: '1'\nparam: '167'\nstep: '0'\nstream: enfo\ntime: '1200'\ntype: pf\n"}}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "POST /api/v1/requests/ecmwf-mars-beta HTTP/1.1" 202 49
# DEBUG:polytope.api.Client.DMFTG0:Polytope client received HTTP SUCCESS (202)
# 2024-11-15 13:25:36 - INFO - Request accepted. Please poll ./2b85268b-0c23-470d-8f7b-d3b73079366d for status
# INFO:polytope.api.Client.DMFTG0:Request accepted. Please poll ./2b85268b-0c23-470d-8f7b-d3b73079366d for status
# DEBUG:polytope.api.Client.DMFTG0:Server message: Request queued
# 2024-11-15 13:25:36 - INFO - Polytope user key found in session cache for user cgr
# INFO:polytope.api.Client.DMFTG0:Polytope user key found in session cache for user cgr
# 2024-11-15 13:25:36 - INFO - Checking request status (./2b85268b-0c23-470d-8f7b-d3b73079366d)...
# INFO:polytope.api.Client.DMFTG0:Checking request status (./2b85268b-0c23-470d-8f7b-d3b73079366d)...
# DEBUG:polytope.api.Client.DMFTG0:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./2b85268b-0c23-470d-8f7b-d3b73079366d
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/2b85268b-0c23-470d-8f7b-d3b73079366d HTTP/1.1" 202 49
# DEBUG:polytope.api.Client.DMFTG0:Polytope client received HTTP SUCCESS (202)
# 2024-11-15 13:25:36 - INFO - The current status of the request is 'queued'
# INFO:polytope.api.Client.DMFTG0:The current status of the request is 'queued'
# DEBUG:polytope.api.Client.DMFTG0:Server message: Request queued
# DEBUG:polytope.api.Client.DMFTG0:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./2b85268b-0c23-470d-8f7b-d3b73079366d
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/2b85268b-0c23-470d-8f7b-d3b73079366d HTTP/1.1" 202 57
# DEBUG:polytope.api.Client.DMFTG0:Polytope client received HTTP SUCCESS (202)
# 2024-11-15 13:25:37 - INFO - The current status of the request is 'processing'
# INFO:polytope.api.Client.DMFTG0:The current status of the request is 'processing'
# DEBUG:polytope.api.Client.DMFTG0:Server message: Request processing
# DEBUG:polytope.api.Client.DMFTG0:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./2b85268b-0c23-470d-8f7b-d3b73079366d
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/2b85268b-0c23-470d-8f7b-d3b73079366d HTTP/1.1" 202 57
# DEBUG:polytope.api.Client.DMFTG0:Polytope client received HTTP SUCCESS (202)
# DEBUG:polytope.api.Client.DMFTG0:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./2b85268b-0c23-470d-8f7b-d3b73079366d
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/2b85268b-0c23-470d-8f7b-d3b73079366d HTTP/1.1" 202 57
# DEBUG:polytope.api.Client.DMFTG0:Polytope client received HTTP SUCCESS (202)
# DEBUG:polytope.api.Client.DMFTG0:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./2b85268b-0c23-470d-8f7b-d3b73079366d
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/2b85268b-0c23-470d-8f7b-d3b73079366d HTTP/1.1" 202 57
# DEBUG:polytope.api.Client.DMFTG0:Polytope client received HTTP SUCCESS (202)
# DEBUG:polytope.api.Client.DMFTG0:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./2b85268b-0c23-470d-8f7b-d3b73079366d
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/2b85268b-0c23-470d-8f7b-d3b73079366d HTTP/1.1" 303 180
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): download-polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://download-polytope-test.ecmwf.int:443 "GET /default/2b85268b-0c23-470d-8f7b-d3b73079366d.covjson HTTP/1.1" 200 2838
# DEBUG:polytope.api.Client.DMFTG0:Polytope client received HTTP SUCCESS (200)
# 2024-11-15 13:25:38 - INFO - The current status of the request is 'processed'
# INFO:polytope.api.Client.DMFTG0:The current status of the request is 'processed'
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): download-polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://download-polytope-test.ecmwf.int:443 "HEAD /default/2b85268b-0c23-470d-8f7b-d3b73079366d.covjson HTTP/1.1" 200 0
# 2b85268b-0c23-470d-8f7b-d3b73079366d.covjson:   0%|          | 0.00/2.77k [00:00<?, ?B/s]
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): download-polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://download-polytope-test.ecmwf.int:443 "GET /default/2b85268b-0c23-470d-8f7b-d3b73079366d.covjson HTTP/1.1" 200 2838
# DEBUG:polytope.api.Client.CQFQB5:Gathered Polytope client configuration:
# {'address': 'polytope-test.ecmwf.int',
#  'insecure': False,
#  'key_path': PosixPath('/Users/cgr/.polytopeapirc'),
#  'log_file': None,
#  'log_level': 'DEBUG',
#  'password': None,
#  'port': None,
#  'quiet': False,
#  'skip_tls': False,
#  'user_email': None,
#  'user_key': None,
#  'username': 'cgr',
#  'verbose': False}
# DEBUG:polytope.api.Client.CQFQB5:Creating Polytope client...
# 2024-11-15 13:25:39 - INFO - Key read from /Users/cgr/.polytopeapirc
# INFO:polytope.api.Client.CQFQB5:Key read from /Users/cgr/.polytopeapirc
# 2024-11-15 13:25:39 - INFO - Sending request...
# {'request': 'class: od\n'
#             "date: '20241114'\n"
#             'domain: g\n'
#             'expver: 1\n'
#             'feature:\n'
#             '  shape:\n'
#             '  - - 8.778584932744309\n'
#             '    - 49.86954658650521\n'
#             '  - - 8.862295524771469\n'
#             '    - 48.766918864990714\n'
#             '  - - 10.061878585703141\n'
#             '    - 48.80521538773752\n'
#             '  - - 10.05189374814043\n'
#             '    - 49.02912712169905\n'
#             '  - - 9.126374708842917\n'
#             '    - 49.035317308040874\n'
#             '  - - 9.054787898083248\n'
#             '    - 49.85647839775169\n'
#             '  - - 8.79447274483195\n'
#             '    - 49.8646339236731\n'
#             '  type: polygon\n'
#             'levtype: sfc\n'
#             "number: '1'\n"
#             "param: '167'\n"
#             "step: '0'\n"
#             'stream: enfo\n'
#             "time: '1200'\n"
#             'type: pf\n',
#  'verb': 'retrieve'}
# INFO:polytope.api.Client.CQFQB5:Sending request...
# {'request': 'class: od\n'
#             "date: '20241114'\n"
#             'domain: g\n'
#             'expver: 1\n'
#             'feature:\n'
#             '  shape:\n'
#             '  - - 8.778584932744309\n'
#             '    - 49.86954658650521\n'
#             '  - - 8.862295524771469\n'
#             '    - 48.766918864990714\n'
#             '  - - 10.061878585703141\n'
#             '    - 48.80521538773752\n'
#             '  - - 10.05189374814043\n'
#             '    - 49.02912712169905\n'
#             '  - - 9.126374708842917\n'
#             '    - 49.035317308040874\n'
#             '  - - 9.054787898083248\n'
#             '    - 49.85647839775169\n'
#             '  - - 8.79447274483195\n'
#             '    - 49.8646339236731\n'
#             '  type: polygon\n'
#             'levtype: sfc\n'
#             "number: '1'\n"
#             "param: '167'\n"
#             "step: '0'\n"
#             'stream: enfo\n'
#             "time: '1200'\n"
#             'type: pf\n',
#  'verb': 'retrieve'}
# 2024-11-15 13:25:39 - INFO - Polytope user key found in session cache for user cgr
# INFO:polytope.api.Client.CQFQB5:Polytope user key found in session cache for user cgr
# DEBUG:polytope.api.Client.CQFQB5:Polytope client attempting HTTP POST https://polytope-test.ecmwf.int:443/api/v1/requests/ecmwf-mars-beta
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': {'verb': 'retrieve', 'request': "class: od\ndate: '20241114'\ndomain: g\nexpver: 1\nfeature:\n  shape:\n  - - 8.778584932744309\n    - 49.86954658650521\n  - - 8.862295524771469\n    - 48.766918864990714\n  - - 10.061878585703141\n    - 48.80521538773752\n  - - 10.05189374814043\n    - 49.02912712169905\n  - - 9.126374708842917\n    - 49.035317308040874\n  - - 9.054787898083248\n    - 49.85647839775169\n  - - 8.79447274483195\n    - 49.8646339236731\n  type: polygon\nlevtype: sfc\nnumber: '1'\nparam: '167'\nstep: '0'\nstream: enfo\ntime: '1200'\ntype: pf\n"}}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "POST /api/v1/requests/ecmwf-mars-beta HTTP/1.1" 202 49
# DEBUG:polytope.api.Client.CQFQB5:Polytope client received HTTP SUCCESS (202)
# 2024-11-15 13:25:39 - INFO - Request accepted. Please poll ./7a933fbc-9a1c-4231-84e7-5b842fdaa37a for status
# INFO:polytope.api.Client.CQFQB5:Request accepted. Please poll ./7a933fbc-9a1c-4231-84e7-5b842fdaa37a for status
# DEBUG:polytope.api.Client.CQFQB5:Server message: Request queued
# 2024-11-15 13:25:39 - INFO - Polytope user key found in session cache for user cgr
# INFO:polytope.api.Client.CQFQB5:Polytope user key found in session cache for user cgr
# 2024-11-15 13:25:39 - INFO - Checking request status (./7a933fbc-9a1c-4231-84e7-5b842fdaa37a)...
# INFO:polytope.api.Client.CQFQB5:Checking request status (./7a933fbc-9a1c-4231-84e7-5b842fdaa37a)...
# DEBUG:polytope.api.Client.CQFQB5:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./7a933fbc-9a1c-4231-84e7-5b842fdaa37a
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/7a933fbc-9a1c-4231-84e7-5b842fdaa37a HTTP/1.1" 202 49
# DEBUG:polytope.api.Client.CQFQB5:Polytope client received HTTP SUCCESS (202)
# 2024-11-15 13:25:39 - INFO - The current status of the request is 'queued'
# INFO:polytope.api.Client.CQFQB5:The current status of the request is 'queued'
# DEBUG:polytope.api.Client.CQFQB5:Server message: Request queued
# DEBUG:polytope.api.Client.CQFQB5:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./7a933fbc-9a1c-4231-84e7-5b842fdaa37a
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/7a933fbc-9a1c-4231-84e7-5b842fdaa37a HTTP/1.1" 202 49
# DEBUG:polytope.api.Client.CQFQB5:Polytope client received HTTP SUCCESS (202)
# DEBUG:polytope.api.Client.CQFQB5:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./7a933fbc-9a1c-4231-84e7-5b842fdaa37a
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/7a933fbc-9a1c-4231-84e7-5b842fdaa37a HTTP/1.1" 202 57
# DEBUG:polytope.api.Client.CQFQB5:Polytope client received HTTP SUCCESS (202)
# 2024-11-15 13:25:40 - INFO - The current status of the request is 'processing'
# INFO:polytope.api.Client.CQFQB5:The current status of the request is 'processing'
# DEBUG:polytope.api.Client.CQFQB5:Server message: Request processing
# DEBUG:polytope.api.Client.CQFQB5:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./7a933fbc-9a1c-4231-84e7-5b842fdaa37a
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/7a933fbc-9a1c-4231-84e7-5b842fdaa37a HTTP/1.1" 202 57
# DEBUG:polytope.api.Client.CQFQB5:Polytope client received HTTP SUCCESS (202)
# DEBUG:polytope.api.Client.CQFQB5:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./7a933fbc-9a1c-4231-84e7-5b842fdaa37a
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/7a933fbc-9a1c-4231-84e7-5b842fdaa37a HTTP/1.1" 202 57
# DEBUG:polytope.api.Client.CQFQB5:Polytope client received HTTP SUCCESS (202)
# DEBUG:polytope.api.Client.CQFQB5:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./7a933fbc-9a1c-4231-84e7-5b842fdaa37a
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/7a933fbc-9a1c-4231-84e7-5b842fdaa37a HTTP/1.1" 202 57
# DEBUG:polytope.api.Client.CQFQB5:Polytope client received HTTP SUCCESS (202)
# DEBUG:polytope.api.Client.CQFQB5:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./7a933fbc-9a1c-4231-84e7-5b842fdaa37a
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/7a933fbc-9a1c-4231-84e7-5b842fdaa37a HTTP/1.1" 303 180
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): download-polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://download-polytope-test.ecmwf.int:443 "GET /default/7a933fbc-9a1c-4231-84e7-5b842fdaa37a.covjson HTTP/1.1" 200 7203
# DEBUG:polytope.api.Client.CQFQB5:Polytope client received HTTP SUCCESS (200)
# 2024-11-15 13:25:41 - INFO - The current status of the request is 'processed'
# INFO:polytope.api.Client.CQFQB5:The current status of the request is 'processed'
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): download-polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://download-polytope-test.ecmwf.int:443 "HEAD /default/7a933fbc-9a1c-4231-84e7-5b842fdaa37a.covjson HTTP/1.1" 200 0
# 7a933fbc-9a1c-4231-84e7-5b842fdaa37a.covjson:   0%|          | 0.00/7.03k [00:00<?, ?B/s]
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): download-polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://download-polytope-test.ecmwf.int:443 "GET /default/7a933fbc-9a1c-4231-84e7-5b842fdaa37a.covjson HTTP/1.1" 200 7203
# DEBUG:polytope.api.Client.GSH6L4:Gathered Polytope client configuration:
# {'address': 'polytope-test.ecmwf.int',
#  'insecure': False,
#  'key_path': PosixPath('/Users/cgr/.polytopeapirc'),
#  'log_file': None,
#  'log_level': 'DEBUG',
#  'password': None,
#  'port': None,
#  'quiet': False,
#  'skip_tls': False,
#  'user_email': None,
#  'user_key': None,
#  'username': 'cgr',
#  'verbose': False}
# DEBUG:polytope.api.Client.GSH6L4:Creating Polytope client...
# 2024-11-15 13:25:42 - INFO - Key read from /Users/cgr/.polytopeapirc
# INFO:polytope.api.Client.GSH6L4:Key read from /Users/cgr/.polytopeapirc
# 2024-11-15 13:25:42 - INFO - Sending request...
# {'request': 'class: od\n'
#             "date: '20241114'\n"
#             'domain: g\n'
#             'expver: 1\n'
#             'feature:\n'
#             '  shape:\n'
#             '  - - 9.088892121315212\n'
#             '    - 49.68396293291025\n'
#             '  - - 9.819571610135483\n'
#             '    - 49.684014501470756\n'
#             '  - - 9.85505960658449\n'
#             '    - 49.03116952568445\n'
#             '  - - 10.060153571012052\n'
#             '    - 49.027505122195635\n'
#             '  - - 10.072160282281033\n'
#             '    - 49.86449197101945\n'
#             '  - - 9.05948442169526\n'
#             '    - 49.85694532601448\n'
#             '  - - 9.071912795654185\n'
#             '    - 49.68014004987609\n'
#             '  type: polygon\n'
#             'levtype: sfc\n'
#             "number: '1'\n"
#             "param: '167'\n"
#             "step: '0'\n"
#             'stream: enfo\n'
#             "time: '1200'\n"
#             'type: pf\n',
#  'verb': 'retrieve'}
# INFO:polytope.api.Client.GSH6L4:Sending request...
# {'request': 'class: od\n'
#             "date: '20241114'\n"
#             'domain: g\n'
#             'expver: 1\n'
#             'feature:\n'
#             '  shape:\n'
#             '  - - 9.088892121315212\n'
#             '    - 49.68396293291025\n'
#             '  - - 9.819571610135483\n'
#             '    - 49.684014501470756\n'
#             '  - - 9.85505960658449\n'
#             '    - 49.03116952568445\n'
#             '  - - 10.060153571012052\n'
#             '    - 49.027505122195635\n'
#             '  - - 10.072160282281033\n'
#             '    - 49.86449197101945\n'
#             '  - - 9.05948442169526\n'
#             '    - 49.85694532601448\n'
#             '  - - 9.071912795654185\n'
#             '    - 49.68014004987609\n'
#             '  type: polygon\n'
#             'levtype: sfc\n'
#             "number: '1'\n"
#             "param: '167'\n"
#             "step: '0'\n"
#             'stream: enfo\n'
#             "time: '1200'\n"
#             'type: pf\n',
#  'verb': 'retrieve'}
# 2024-11-15 13:25:42 - INFO - Polytope user key found in session cache for user cgr
# INFO:polytope.api.Client.GSH6L4:Polytope user key found in session cache for user cgr
# DEBUG:polytope.api.Client.GSH6L4:Polytope client attempting HTTP POST https://polytope-test.ecmwf.int:443/api/v1/requests/ecmwf-mars-beta
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': {'verb': 'retrieve', 'request': "class: od\ndate: '20241114'\ndomain: g\nexpver: 1\nfeature:\n  shape:\n  - - 9.088892121315212\n    - 49.68396293291025\n  - - 9.819571610135483\n    - 49.684014501470756\n  - - 9.85505960658449\n    - 49.03116952568445\n  - - 10.060153571012052\n    - 49.027505122195635\n  - - 10.072160282281033\n    - 49.86449197101945\n  - - 9.05948442169526\n    - 49.85694532601448\n  - - 9.071912795654185\n    - 49.68014004987609\n  type: polygon\nlevtype: sfc\nnumber: '1'\nparam: '167'\nstep: '0'\nstream: enfo\ntime: '1200'\ntype: pf\n"}}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "POST /api/v1/requests/ecmwf-mars-beta HTTP/1.1" 202 49
# DEBUG:polytope.api.Client.GSH6L4:Polytope client received HTTP SUCCESS (202)
# 2024-11-15 13:25:42 - INFO - Request accepted. Please poll ./b93ddc09-9419-45cc-a120-335286b10a6f for status
# INFO:polytope.api.Client.GSH6L4:Request accepted. Please poll ./b93ddc09-9419-45cc-a120-335286b10a6f for status
# DEBUG:polytope.api.Client.GSH6L4:Server message: Request queued
# 2024-11-15 13:25:42 - INFO - Polytope user key found in session cache for user cgr
# INFO:polytope.api.Client.GSH6L4:Polytope user key found in session cache for user cgr
# 2024-11-15 13:25:42 - INFO - Checking request status (./b93ddc09-9419-45cc-a120-335286b10a6f)...
# INFO:polytope.api.Client.GSH6L4:Checking request status (./b93ddc09-9419-45cc-a120-335286b10a6f)...
# DEBUG:polytope.api.Client.GSH6L4:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./b93ddc09-9419-45cc-a120-335286b10a6f
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/b93ddc09-9419-45cc-a120-335286b10a6f HTTP/1.1" 202 49
# DEBUG:polytope.api.Client.GSH6L4:Polytope client received HTTP SUCCESS (202)
# 2024-11-15 13:25:42 - INFO - The current status of the request is 'queued'
# INFO:polytope.api.Client.GSH6L4:The current status of the request is 'queued'
# DEBUG:polytope.api.Client.GSH6L4:Server message: Request queued
# DEBUG:polytope.api.Client.GSH6L4:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./b93ddc09-9419-45cc-a120-335286b10a6f
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/b93ddc09-9419-45cc-a120-335286b10a6f HTTP/1.1" 202 57
# DEBUG:polytope.api.Client.GSH6L4:Polytope client received HTTP SUCCESS (202)
# 2024-11-15 13:25:42 - INFO - The current status of the request is 'processing'
# INFO:polytope.api.Client.GSH6L4:The current status of the request is 'processing'
# DEBUG:polytope.api.Client.GSH6L4:Server message: Request processing
# DEBUG:polytope.api.Client.GSH6L4:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./b93ddc09-9419-45cc-a120-335286b10a6f
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/b93ddc09-9419-45cc-a120-335286b10a6f HTTP/1.1" 202 57
# DEBUG:polytope.api.Client.GSH6L4:Polytope client received HTTP SUCCESS (202)
# DEBUG:polytope.api.Client.GSH6L4:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./b93ddc09-9419-45cc-a120-335286b10a6f
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/b93ddc09-9419-45cc-a120-335286b10a6f HTTP/1.1" 202 57
# DEBUG:polytope.api.Client.GSH6L4:Polytope client received HTTP SUCCESS (202)
# DEBUG:polytope.api.Client.GSH6L4:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./b93ddc09-9419-45cc-a120-335286b10a6f
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/b93ddc09-9419-45cc-a120-335286b10a6f HTTP/1.1" 202 57
# DEBUG:polytope.api.Client.GSH6L4:Polytope client received HTTP SUCCESS (202)
# DEBUG:polytope.api.Client.GSH6L4:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./b93ddc09-9419-45cc-a120-335286b10a6f
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/b93ddc09-9419-45cc-a120-335286b10a6f HTTP/1.1" 303 180
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): download-polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://download-polytope-test.ecmwf.int:443 "GET /default/b93ddc09-9419-45cc-a120-335286b10a6f.covjson HTTP/1.1" 200 4818
# DEBUG:polytope.api.Client.GSH6L4:Polytope client received HTTP SUCCESS (200)
# 2024-11-15 13:25:44 - INFO - The current status of the request is 'processed'
# INFO:polytope.api.Client.GSH6L4:The current status of the request is 'processed'
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): download-polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://download-polytope-test.ecmwf.int:443 "HEAD /default/b93ddc09-9419-45cc-a120-335286b10a6f.covjson HTTP/1.1" 200 0
# b93ddc09-9419-45cc-a120-335286b10a6f.covjson:   0%|          | 0.00/4.71k [00:00<?, ?B/s]
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): download-polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://download-polytope-test.ecmwf.int:443 "GET /default/b93ddc09-9419-45cc-a120-335286b10a6f.covjson HTTP/1.1" 200 4818
# DEBUG:polytope.api.Client.G3A9V0:Gathered Polytope client configuration:
# {'address': 'polytope-test.ecmwf.int',
#  'insecure': False,
#  'key_path': PosixPath('/Users/cgr/.polytopeapirc'),
#  'log_file': None,
#  'log_level': 'DEBUG',
#  'password': None,
#  'port': None,
#  'quiet': False,
#  'skip_tls': False,
#  'user_email': None,
#  'user_key': None,
#  'username': 'cgr',
#  'verbose': False}
# DEBUG:polytope.api.Client.G3A9V0:Creating Polytope client...
# 2024-11-15 13:25:45 - INFO - Key read from /Users/cgr/.polytopeapirc
# INFO:polytope.api.Client.G3A9V0:Key read from /Users/cgr/.polytopeapirc
# 2024-11-15 13:25:45 - INFO - Sending request...
# {'request': 'class: od\n'
#             "date: '20241114'\n"
#             'domain: g\n'
#             'expver: 1\n'
#             'feature:\n'
#             '  shape:\n'
#             '  - - 10.598471035757996\n'
#             '    - 49.82012849229719\n'
#             '  - - 10.623393389597027\n'
#             '    - 48.824858944891844\n'
#             '  - - 12.04024144738159\n'
#             '    - 48.83198005307881\n'
#             '  - - 12.006769966371252\n'
#             '    - 49.16097358155085\n'
#             '  - - 10.989756517888907\n'
#             '    - 49.16815641449875\n'
#             '  - - 10.948052430339942\n'
#             '    - 49.88592726422476\n'
#             '  - - 10.596882802957197\n'
#             '    - 49.86398061258498\n'
#             '  type: polygon\n'
#             'levtype: sfc\n'
#             "number: '1'\n"
#             "param: '167'\n"
#             "step: '0'\n"
#             'stream: enfo\n'
#             "time: '1200'\n"
#             'type: pf\n',
#  'verb': 'retrieve'}
# INFO:polytope.api.Client.G3A9V0:Sending request...
# {'request': 'class: od\n'
#             "date: '20241114'\n"
#             'domain: g\n'
#             'expver: 1\n'
#             'feature:\n'
#             '  shape:\n'
#             '  - - 10.598471035757996\n'
#             '    - 49.82012849229719\n'
#             '  - - 10.623393389597027\n'
#             '    - 48.824858944891844\n'
#             '  - - 12.04024144738159\n'
#             '    - 48.83198005307881\n'
#             '  - - 12.006769966371252\n'
#             '    - 49.16097358155085\n'
#             '  - - 10.989756517888907\n'
#             '    - 49.16815641449875\n'
#             '  - - 10.948052430339942\n'
#             '    - 49.88592726422476\n'
#             '  - - 10.596882802957197\n'
#             '    - 49.86398061258498\n'
#             '  type: polygon\n'
#             'levtype: sfc\n'
#             "number: '1'\n"
#             "param: '167'\n"
#             "step: '0'\n"
#             'stream: enfo\n'
#             "time: '1200'\n"
#             'type: pf\n',
#  'verb': 'retrieve'}
# 2024-11-15 13:25:45 - INFO - Polytope user key found in session cache for user cgr
# INFO:polytope.api.Client.G3A9V0:Polytope user key found in session cache for user cgr
# DEBUG:polytope.api.Client.G3A9V0:Polytope client attempting HTTP POST https://polytope-test.ecmwf.int:443/api/v1/requests/ecmwf-mars-beta
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': {'verb': 'retrieve', 'request': "class: od\ndate: '20241114'\ndomain: g\nexpver: 1\nfeature:\n  shape:\n  - - 10.598471035757996\n    - 49.82012849229719\n  - - 10.623393389597027\n    - 48.824858944891844\n  - - 12.04024144738159\n    - 48.83198005307881\n  - - 12.006769966371252\n    - 49.16097358155085\n  - - 10.989756517888907\n    - 49.16815641449875\n  - - 10.948052430339942\n    - 49.88592726422476\n  - - 10.596882802957197\n    - 49.86398061258498\n  type: polygon\nlevtype: sfc\nnumber: '1'\nparam: '167'\nstep: '0'\nstream: enfo\ntime: '1200'\ntype: pf\n"}}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "POST /api/v1/requests/ecmwf-mars-beta HTTP/1.1" 202 49
# DEBUG:polytope.api.Client.G3A9V0:Polytope client received HTTP SUCCESS (202)
# 2024-11-15 13:25:45 - INFO - Request accepted. Please poll ./ab0c2362-f1a6-4b3a-8b3a-6cb2df45a935 for status
# INFO:polytope.api.Client.G3A9V0:Request accepted. Please poll ./ab0c2362-f1a6-4b3a-8b3a-6cb2df45a935 for status
# DEBUG:polytope.api.Client.G3A9V0:Server message: Request queued
# 2024-11-15 13:25:45 - INFO - Polytope user key found in session cache for user cgr
# INFO:polytope.api.Client.G3A9V0:Polytope user key found in session cache for user cgr
# 2024-11-15 13:25:45 - INFO - Checking request status (./ab0c2362-f1a6-4b3a-8b3a-6cb2df45a935)...
# INFO:polytope.api.Client.G3A9V0:Checking request status (./ab0c2362-f1a6-4b3a-8b3a-6cb2df45a935)...
# DEBUG:polytope.api.Client.G3A9V0:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./ab0c2362-f1a6-4b3a-8b3a-6cb2df45a935
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/ab0c2362-f1a6-4b3a-8b3a-6cb2df45a935 HTTP/1.1" 202 49
# DEBUG:polytope.api.Client.G3A9V0:Polytope client received HTTP SUCCESS (202)
# 2024-11-15 13:25:45 - INFO - The current status of the request is 'queued'
# INFO:polytope.api.Client.G3A9V0:The current status of the request is 'queued'
# DEBUG:polytope.api.Client.G3A9V0:Server message: Request queued
# DEBUG:polytope.api.Client.G3A9V0:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./ab0c2362-f1a6-4b3a-8b3a-6cb2df45a935
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/ab0c2362-f1a6-4b3a-8b3a-6cb2df45a935 HTTP/1.1" 202 49
# DEBUG:polytope.api.Client.G3A9V0:Polytope client received HTTP SUCCESS (202)
# DEBUG:polytope.api.Client.G3A9V0:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./ab0c2362-f1a6-4b3a-8b3a-6cb2df45a935
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/ab0c2362-f1a6-4b3a-8b3a-6cb2df45a935 HTTP/1.1" 202 57
# DEBUG:polytope.api.Client.G3A9V0:Polytope client received HTTP SUCCESS (202)
# 2024-11-15 13:25:46 - INFO - The current status of the request is 'processing'
# INFO:polytope.api.Client.G3A9V0:The current status of the request is 'processing'
# DEBUG:polytope.api.Client.G3A9V0:Server message: Request processing
# DEBUG:polytope.api.Client.G3A9V0:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./ab0c2362-f1a6-4b3a-8b3a-6cb2df45a935
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/ab0c2362-f1a6-4b3a-8b3a-6cb2df45a935 HTTP/1.1" 202 57
# DEBUG:polytope.api.Client.G3A9V0:Polytope client received HTTP SUCCESS (202)
# DEBUG:polytope.api.Client.G3A9V0:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./ab0c2362-f1a6-4b3a-8b3a-6cb2df45a935
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/ab0c2362-f1a6-4b3a-8b3a-6cb2df45a935 HTTP/1.1" 202 57
# DEBUG:polytope.api.Client.G3A9V0:Polytope client received HTTP SUCCESS (202)
# DEBUG:polytope.api.Client.G3A9V0:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./ab0c2362-f1a6-4b3a-8b3a-6cb2df45a935
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/ab0c2362-f1a6-4b3a-8b3a-6cb2df45a935 HTTP/1.1" 202 57
# DEBUG:polytope.api.Client.G3A9V0:Polytope client received HTTP SUCCESS (202)
# DEBUG:polytope.api.Client.G3A9V0:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./ab0c2362-f1a6-4b3a-8b3a-6cb2df45a935
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/ab0c2362-f1a6-4b3a-8b3a-6cb2df45a935 HTTP/1.1" 303 180
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): download-polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://download-polytope-test.ecmwf.int:443 "GET /default/ab0c2362-f1a6-4b3a-8b3a-6cb2df45a935.covjson HTTP/1.1" 200 9059
# DEBUG:polytope.api.Client.G3A9V0:Polytope client received HTTP SUCCESS (200)
# 2024-11-15 13:25:47 - INFO - The current status of the request is 'processed'
# INFO:polytope.api.Client.G3A9V0:The current status of the request is 'processed'
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): download-polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://download-polytope-test.ecmwf.int:443 "HEAD /default/ab0c2362-f1a6-4b3a-8b3a-6cb2df45a935.covjson HTTP/1.1" 200 0
# ab0c2362-f1a6-4b3a-8b3a-6cb2df45a935.covjson:   0%|          | 0.00/8.85k [00:00<?, ?B/s]
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): download-polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://download-polytope-test.ecmwf.int:443 "GET /default/ab0c2362-f1a6-4b3a-8b3a-6cb2df45a935.covjson HTTP/1.1" 200 9059
# DEBUG:polytope.api.Client.F4FJ9Y:Gathered Polytope client configuration:
# {'address': 'polytope-test.ecmwf.int',
#  'insecure': False,
#  'key_path': PosixPath('/Users/cgr/.polytopeapirc'),
#  'log_file': None,
#  'log_level': 'DEBUG',
#  'password': None,
#  'port': None,
#  'quiet': False,
#  'skip_tls': False,
#  'user_email': None,
#  'user_key': None,
#  'username': 'cgr',
#  'verbose': False}
# DEBUG:polytope.api.Client.F4FJ9Y:Creating Polytope client...
# 2024-11-15 13:25:48 - INFO - Key read from /Users/cgr/.polytopeapirc
# INFO:polytope.api.Client.F4FJ9Y:Key read from /Users/cgr/.polytopeapirc
# 2024-11-15 13:25:48 - INFO - Sending request...
# {'request': 'class: od\n'
#             "date: '20241114'\n"
#             'domain: g\n'
#             'expver: 1\n'
#             'feature:\n'
#             '  shape:\n'
#             '  - - 13.29197987307927\n'
#             '    - 49.97728585641272\n'
#             '  - - 12.57111275146977\n'
#             '    - 49.97104094778115\n'
#             '  - - 13.222322323273431\n'
#             '    - 49.37725327518439\n'
#             '  - - 13.202971158951414\n'
#             '    - 48.903129615084254\n'
#             '  - - 13.827804957331438\n'
#             '    - 48.88340416595227\n'
#             '  - - 13.874384556433938\n'
#             '    - 49.40358865952578\n'
#             '  - - 14.605299546055448\n'
#             '    - 49.93197478940584\n'
#             '  - - 14.102062445091747\n'
#             '    - 49.98001098000407\n'
#             '  - - 13.624487089218775\n'
#             '    - 49.55461007587729\n'
#             '  - - 13.3099890365134\n'
#             '    - 49.97739580806973\n'
#             '  type: polygon\n'
#             'levtype: sfc\n'
#             "number: '1'\n"
#             "param: '167'\n"
#             "step: '0'\n"
#             'stream: enfo\n'
#             "time: '1200'\n"
#             'type: pf\n',
#  'verb': 'retrieve'}
# INFO:polytope.api.Client.F4FJ9Y:Sending request...
# {'request': 'class: od\n'
#             "date: '20241114'\n"
#             'domain: g\n'
#             'expver: 1\n'
#             'feature:\n'
#             '  shape:\n'
#             '  - - 13.29197987307927\n'
#             '    - 49.97728585641272\n'
#             '  - - 12.57111275146977\n'
#             '    - 49.97104094778115\n'
#             '  - - 13.222322323273431\n'
#             '    - 49.37725327518439\n'
#             '  - - 13.202971158951414\n'
#             '    - 48.903129615084254\n'
#             '  - - 13.827804957331438\n'
#             '    - 48.88340416595227\n'
#             '  - - 13.874384556433938\n'
#             '    - 49.40358865952578\n'
#             '  - - 14.605299546055448\n'
#             '    - 49.93197478940584\n'
#             '  - - 14.102062445091747\n'
#             '    - 49.98001098000407\n'
#             '  - - 13.624487089218775\n'
#             '    - 49.55461007587729\n'
#             '  - - 13.3099890365134\n'
#             '    - 49.97739580806973\n'
#             '  type: polygon\n'
#             'levtype: sfc\n'
#             "number: '1'\n"
#             "param: '167'\n"
#             "step: '0'\n"
#             'stream: enfo\n'
#             "time: '1200'\n"
#             'type: pf\n',
#  'verb': 'retrieve'}
# 2024-11-15 13:25:48 - INFO - Polytope user key found in session cache for user cgr
# INFO:polytope.api.Client.F4FJ9Y:Polytope user key found in session cache for user cgr
# DEBUG:polytope.api.Client.F4FJ9Y:Polytope client attempting HTTP POST https://polytope-test.ecmwf.int:443/api/v1/requests/ecmwf-mars-beta
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': {'verb': 'retrieve', 'request': "class: od\ndate: '20241114'\ndomain: g\nexpver: 1\nfeature:\n  shape:\n  - - 13.29197987307927\n    - 49.97728585641272\n  - - 12.57111275146977\n    - 49.97104094778115\n  - - 13.222322323273431\n    - 49.37725327518439\n  - - 13.202971158951414\n    - 48.903129615084254\n  - - 13.827804957331438\n    - 48.88340416595227\n  - - 13.874384556433938\n    - 49.40358865952578\n  - - 14.605299546055448\n    - 49.93197478940584\n  - - 14.102062445091747\n    - 49.98001098000407\n  - - 13.624487089218775\n    - 49.55461007587729\n  - - 13.3099890365134\n    - 49.97739580806973\n  type: polygon\nlevtype: sfc\nnumber: '1'\nparam: '167'\nstep: '0'\nstream: enfo\ntime: '1200'\ntype: pf\n"}}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "POST /api/v1/requests/ecmwf-mars-beta HTTP/1.1" 202 49
# DEBUG:polytope.api.Client.F4FJ9Y:Polytope client received HTTP SUCCESS (202)
# 2024-11-15 13:25:48 - INFO - Request accepted. Please poll ./29b9f25a-d55b-4ae4-9516-c4a10d5acfae for status
# INFO:polytope.api.Client.F4FJ9Y:Request accepted. Please poll ./29b9f25a-d55b-4ae4-9516-c4a10d5acfae for status
# DEBUG:polytope.api.Client.F4FJ9Y:Server message: Request queued
# 2024-11-15 13:25:48 - INFO - Polytope user key found in session cache for user cgr
# INFO:polytope.api.Client.F4FJ9Y:Polytope user key found in session cache for user cgr
# 2024-11-15 13:25:48 - INFO - Checking request status (./29b9f25a-d55b-4ae4-9516-c4a10d5acfae)...
# INFO:polytope.api.Client.F4FJ9Y:Checking request status (./29b9f25a-d55b-4ae4-9516-c4a10d5acfae)...
# DEBUG:polytope.api.Client.F4FJ9Y:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./29b9f25a-d55b-4ae4-9516-c4a10d5acfae
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/29b9f25a-d55b-4ae4-9516-c4a10d5acfae HTTP/1.1" 202 49
# DEBUG:polytope.api.Client.F4FJ9Y:Polytope client received HTTP SUCCESS (202)
# 2024-11-15 13:25:48 - INFO - The current status of the request is 'queued'
# INFO:polytope.api.Client.F4FJ9Y:The current status of the request is 'queued'
# DEBUG:polytope.api.Client.F4FJ9Y:Server message: Request queued
# DEBUG:polytope.api.Client.F4FJ9Y:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./29b9f25a-d55b-4ae4-9516-c4a10d5acfae
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/29b9f25a-d55b-4ae4-9516-c4a10d5acfae HTTP/1.1" 202 57
# DEBUG:polytope.api.Client.F4FJ9Y:Polytope client received HTTP SUCCESS (202)
# 2024-11-15 13:25:48 - INFO - The current status of the request is 'processing'
# INFO:polytope.api.Client.F4FJ9Y:The current status of the request is 'processing'
# DEBUG:polytope.api.Client.F4FJ9Y:Server message: Request processing
# DEBUG:polytope.api.Client.F4FJ9Y:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./29b9f25a-d55b-4ae4-9516-c4a10d5acfae
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# ...
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/ba8ca7d1-3fab-40c0-a527-ae1c3abf367f HTTP/1.1" 202 49
# DEBUG:polytope.api.Client.8WXLNS:Polytope client received HTTP SUCCESS (202)
# 2024-11-15 13:26:03 - INFO - The current status of the request is 'queued'
# INFO:polytope.api.Client.8WXLNS:The current status of the request is 'queued'
# DEBUG:polytope.api.Client.8WXLNS:Server message: Request queued
# DEBUG:polytope.api.Client.8WXLNS:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./ba8ca7d1-3fab-40c0-a527-ae1c3abf367f
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/ba8ca7d1-3fab-40c0-a527-ae1c3abf367f HTTP/1.1" 202 57
# DEBUG:polytope.api.Client.8WXLNS:Polytope client received HTTP SUCCESS (202)
# 2024-11-15 13:26:04 - INFO - The current status of the request is 'processing'
# INFO:polytope.api.Client.8WXLNS:The current status of the request is 'processing'
# DEBUG:polytope.api.Client.8WXLNS:Server message: Request processing
# DEBUG:polytope.api.Client.8WXLNS:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./ba8ca7d1-3fab-40c0-a527-ae1c3abf367f
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/ba8ca7d1-3fab-40c0-a527-ae1c3abf367f HTTP/1.1" 202 57
# DEBUG:polytope.api.Client.8WXLNS:Polytope client received HTTP SUCCESS (202)
# DEBUG:polytope.api.Client.8WXLNS:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./ba8ca7d1-3fab-40c0-a527-ae1c3abf367f
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/ba8ca7d1-3fab-40c0-a527-ae1c3abf367f HTTP/1.1" 202 57
# DEBUG:polytope.api.Client.8WXLNS:Polytope client received HTTP SUCCESS (202)
# DEBUG:polytope.api.Client.8WXLNS:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./ba8ca7d1-3fab-40c0-a527-ae1c3abf367f
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/ba8ca7d1-3fab-40c0-a527-ae1c3abf367f HTTP/1.1" 202 57
# DEBUG:polytope.api.Client.8WXLNS:Polytope client received HTTP SUCCESS (202)
# DEBUG:polytope.api.Client.8WXLNS:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./ba8ca7d1-3fab-40c0-a527-ae1c3abf367f
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/ba8ca7d1-3fab-40c0-a527-ae1c3abf367f HTTP/1.1" 202 57
# DEBUG:polytope.api.Client.8WXLNS:Polytope client received HTTP SUCCESS (202)
# DEBUG:polytope.api.Client.8WXLNS:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./ba8ca7d1-3fab-40c0-a527-ae1c3abf367f
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/ba8ca7d1-3fab-40c0-a527-ae1c3abf367f HTTP/1.1" 303 180
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): download-polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://download-polytope-test.ecmwf.int:443 "GET /default/ba8ca7d1-3fab-40c0-a527-ae1c3abf367f.covjson HTTP/1.1" 200 2861
# DEBUG:polytope.api.Client.8WXLNS:Polytope client received HTTP SUCCESS (200)
# 2024-11-15 13:26:06 - INFO - The current status of the request is 'processed'
# INFO:polytope.api.Client.8WXLNS:The current status of the request is 'processed'
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): download-polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://download-polytope-test.ecmwf.int:443 "HEAD /default/ba8ca7d1-3fab-40c0-a527-ae1c3abf367f.covjson HTTP/1.1" 200 0
# ba8ca7d1-3fab-40c0-a527-ae1c3abf367f.covjson:   0%|          | 0.00/2.79k [00:00<?, ?B/s]
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): download-polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://download-polytope-test.ecmwf.int:443 "GET /default/ba8ca7d1-3fab-40c0-a527-ae1c3abf367f.covjson HTTP/1.1" 200 2861
# DEBUG:polytope.api.Client.87VA4Z:Gathered Polytope client configuration:
# {'address': 'polytope-test.ecmwf.int',
#  'insecure': False,
#  'key_path': PosixPath('/Users/cgr/.polytopeapirc'),
#  'log_file': None,
#  'log_level': 'DEBUG',
#  'password': None,
#  'port': None,
#  'quiet': False,
#  'skip_tls': False,
#  'user_email': None,
#  'user_key': None,
#  'username': 'cgr',
#  'verbose': False}
# DEBUG:polytope.api.Client.87VA4Z:Creating Polytope client...
# 2024-11-15 13:26:06 - INFO - Key read from /Users/cgr/.polytopeapirc
# INFO:polytope.api.Client.87VA4Z:Key read from /Users/cgr/.polytopeapirc
# 2024-11-15 13:26:06 - INFO - Sending request...
# {'request': 'class: od\n'
#             "date: '20241114'\n"
#             'domain: g\n'
#             'expver: 1\n'
#             'feature:\n'
#             '  shape:\n'
#             '  - - 23.208137901360374\n'
#             '    - 49.651584260796994\n'
#             '  - - 22.09658437133257\n'
#             '    - 49.752545184049126\n'
#             '  - - 21.91802865423628\n'
#             '    - 48.67264127283525\n'
#             '  - - 23.391185304246818\n'
#             '    - 48.62884428299256\n'
#             '  - - 23.420678366377672\n'
#             '    - 48.95370738548149\n'
#             '  - - 22.47620509293023\n'
#             '    - 48.948108124274114\n'
#             '  - - 22.504379835652145\n'
#             '    - 49.154931298807696\n'
#             '  - - 23.380718740911448\n'
#             '    - 49.134280180441834\n'
#             '  - - 23.347965550435475\n'
#             '    - 49.36007407350195\n'
#             '  - - 22.508043914644247\n'
#             '    - 49.34861103718032\n'
#             '  - - 22.552065252592882\n'
#             '    - 49.49663569230876\n'
#             '  - - 23.44022825068265\n'
#             '    - 49.49121931651345\n'
#             '  - - 23.257411122842967\n'
#             '    - 49.664632737235905\n'
#             '  type: polygon\n'
#             'levtype: sfc\n'
#             "number: '1'\n"
#             "param: '167'\n"
#             "step: '0'\n"
#             'stream: enfo\n'
#             "time: '1200'\n"
#             'type: pf\n',
#  'verb': 'retrieve'}
# INFO:polytope.api.Client.87VA4Z:Sending request...
# {'request': 'class: od\n'
#             "date: '20241114'\n"
#             'domain: g\n'
#             'expver: 1\n'
#             'feature:\n'
#             '  shape:\n'
#             '  - - 23.208137901360374\n'
#             '    - 49.651584260796994\n'
#             '  - - 22.09658437133257\n'
#             '    - 49.752545184049126\n'
#             '  - - 21.91802865423628\n'
#             '    - 48.67264127283525\n'
#             '  - - 23.391185304246818\n'
#             '    - 48.62884428299256\n'
#             '  - - 23.420678366377672\n'
#             '    - 48.95370738548149\n'
#             '  - - 22.47620509293023\n'
#             '    - 48.948108124274114\n'
#             '  - - 22.504379835652145\n'
#             '    - 49.154931298807696\n'
#             '  - - 23.380718740911448\n'
#             '    - 49.134280180441834\n'
#             '  - - 23.347965550435475\n'
#             '    - 49.36007407350195\n'
#             '  - - 22.508043914644247\n'
#             '    - 49.34861103718032\n'
#             '  - - 22.552065252592882\n'
#             '    - 49.49663569230876\n'
#             '  - - 23.44022825068265\n'
#             '    - 49.49121931651345\n'
#             '  - - 23.257411122842967\n'
#             '    - 49.664632737235905\n'
#             '  type: polygon\n'
#             'levtype: sfc\n'
#             "number: '1'\n"
#             "param: '167'\n"
#             "step: '0'\n"
#             'stream: enfo\n'
#             "time: '1200'\n"
#             'type: pf\n',
#  'verb': 'retrieve'}
# 2024-11-15 13:26:06 - INFO - Polytope user key found in session cache for user cgr
# INFO:polytope.api.Client.87VA4Z:Polytope user key found in session cache for user cgr
# DEBUG:polytope.api.Client.87VA4Z:Polytope client attempting HTTP POST https://polytope-test.ecmwf.int:443/api/v1/requests/ecmwf-mars-beta
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': {'verb': 'retrieve', 'request': "class: od\ndate: '20241114'\ndomain: g\nexpver: 1\nfeature:\n  shape:\n  - - 23.208137901360374\n    - 49.651584260796994\n  - - 22.09658437133257\n    - 49.752545184049126\n  - - 21.91802865423628\n    - 48.67264127283525\n  - - 23.391185304246818\n    - 48.62884428299256\n  - - 23.420678366377672\n    - 48.95370738548149\n  - - 22.47620509293023\n    - 48.948108124274114\n  - - 22.504379835652145\n    - 49.154931298807696\n  - - 23.380718740911448\n    - 49.134280180441834\n  - - 23.347965550435475\n    - 49.36007407350195\n  - - 22.508043914644247\n    - 49.34861103718032\n  - - 22.552065252592882\n    - 49.49663569230876\n  - - 23.44022825068265\n    - 49.49121931651345\n  - - 23.257411122842967\n    - 49.664632737235905\n  type: polygon\nlevtype: sfc\nnumber: '1'\nparam: '167'\nstep: '0'\nstream: enfo\ntime: '1200'\ntype: pf\n"}}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "POST /api/v1/requests/ecmwf-mars-beta HTTP/1.1" 202 49
# DEBUG:polytope.api.Client.87VA4Z:Polytope client received HTTP SUCCESS (202)
# 2024-11-15 13:26:06 - INFO - Request accepted. Please poll ./3c4de750-8ad4-4d0f-a694-8990995177fa for status
# INFO:polytope.api.Client.87VA4Z:Request accepted. Please poll ./3c4de750-8ad4-4d0f-a694-8990995177fa for status
# DEBUG:polytope.api.Client.87VA4Z:Server message: Request queued
# 2024-11-15 13:26:06 - INFO - Polytope user key found in session cache for user cgr
# INFO:polytope.api.Client.87VA4Z:Polytope user key found in session cache for user cgr
# 2024-11-15 13:26:06 - INFO - Checking request status (./3c4de750-8ad4-4d0f-a694-8990995177fa)...
# INFO:polytope.api.Client.87VA4Z:Checking request status (./3c4de750-8ad4-4d0f-a694-8990995177fa)...
# DEBUG:polytope.api.Client.87VA4Z:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./3c4de750-8ad4-4d0f-a694-8990995177fa
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/3c4de750-8ad4-4d0f-a694-8990995177fa HTTP/1.1" 202 49
# DEBUG:polytope.api.Client.87VA4Z:Polytope client received HTTP SUCCESS (202)
# 2024-11-15 13:26:06 - INFO - The current status of the request is 'queued'
# INFO:polytope.api.Client.87VA4Z:The current status of the request is 'queued'
# DEBUG:polytope.api.Client.87VA4Z:Server message: Request queued
# DEBUG:polytope.api.Client.87VA4Z:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./3c4de750-8ad4-4d0f-a694-8990995177fa
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/3c4de750-8ad4-4d0f-a694-8990995177fa HTTP/1.1" 202 57
# DEBUG:polytope.api.Client.87VA4Z:Polytope client received HTTP SUCCESS (202)
# 2024-11-15 13:26:07 - INFO - The current status of the request is 'processing'
# INFO:polytope.api.Client.87VA4Z:The current status of the request is 'processing'
# DEBUG:polytope.api.Client.87VA4Z:Server message: Request processing
# DEBUG:polytope.api.Client.87VA4Z:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./3c4de750-8ad4-4d0f-a694-8990995177fa
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/3c4de750-8ad4-4d0f-a694-8990995177fa HTTP/1.1" 202 57
# DEBUG:polytope.api.Client.87VA4Z:Polytope client received HTTP SUCCESS (202)
# DEBUG:polytope.api.Client.87VA4Z:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./3c4de750-8ad4-4d0f-a694-8990995177fa
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/3c4de750-8ad4-4d0f-a694-8990995177fa HTTP/1.1" 202 57
# DEBUG:polytope.api.Client.87VA4Z:Polytope client received HTTP SUCCESS (202)
# DEBUG:polytope.api.Client.87VA4Z:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./3c4de750-8ad4-4d0f-a694-8990995177fa
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/3c4de750-8ad4-4d0f-a694-8990995177fa HTTP/1.1" 202 57
# DEBUG:polytope.api.Client.87VA4Z:Polytope client received HTTP SUCCESS (202)
# DEBUG:polytope.api.Client.87VA4Z:Polytope client attempting HTTP GET https://polytope-test.ecmwf.int:443/api/v1/requests/./3c4de750-8ad4-4d0f-a694-8990995177fa
# {'headers': {'Authorization': 'EmailKey Sandor.Kertesz@ecmwf.int:c2a9188442452fc6cf3a881cfa689648'}, 'json': None}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://polytope-test.ecmwf.int:443 "GET /api/v1/requests/3c4de750-8ad4-4d0f-a694-8990995177fa HTTP/1.1" 303 181
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): download-polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://download-polytope-test.ecmwf.int:443 "GET /default/3c4de750-8ad4-4d0f-a694-8990995177fa.covjson HTTP/1.1" 200 11692
# DEBUG:polytope.api.Client.87VA4Z:Polytope client received HTTP SUCCESS (200)
# 2024-11-15 13:26:08 - INFO - The current status of the request is 'processed'
# INFO:polytope.api.Client.87VA4Z:The current status of the request is 'processed'
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): download-polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://download-polytope-test.ecmwf.int:443 "HEAD /default/3c4de750-8ad4-4d0f-a694-8990995177fa.covjson HTTP/1.1" 200 0
# 3c4de750-8ad4-4d0f-a694-8990995177fa.covjson:   0%|          | 0.00/11.4k [00:00<?, ?B/s]
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): download-polytope-test.ecmwf.int:443
# DEBUG:urllib3.connectionpool:https://download-polytope-test.ecmwf.int:443 "GET /default/3c4de750-8ad4-4d0f-a694-8990995177fa.covjson HTTP/1.1" 200 11692
